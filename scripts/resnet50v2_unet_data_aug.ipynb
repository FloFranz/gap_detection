# %% [markdown]
# ## 1. libraries import and setup

# %%
from pathlib import Path
import importlib.util
import rioxarray as rxr
import tensorflow as tf
from tensorflow_examples.models.pix2pix import pix2pix
from matplotlib import pyplot as plt
import multiprocessing
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# load the setup.py module
path = Path.cwd().parent / 'src' / 'setup.py'
spec = importlib.util.spec_from_file_location('setup', path)
setup = importlib.util.module_from_spec(spec)
spec.loader.exec_module(setup)

# call the make_folders function
raw_data_dir, processed_data_dir, output_dir = setup.make_folders()
# Out:
# created directory data\raw_data\nDSM
# created directory data\raw_data\DOP
# created directory data\raw_data\gaps_poly
# created directory data\processed_data
# created directory data\metadata
# created directory output

# %% [markdown]
# ## 2. data reading and preparation

# %%
# read preprocessed dataset (DOP for training with gap mask)
train_dataset = rxr.open_rasterio(processed_data_dir / 'dop_train_clipped_gapmask.tif',
                                  band_as_variable=True)

# use the long_names as variable names 
# (previously assigned in script 'data_preparation')
for var_name in train_dataset.data_vars:
    long_name = train_dataset[var_name].attrs['long_name']
    train_dataset = train_dataset.rename({var_name: long_name})

train_dataset
# Out:
# <xarray.Dataset>
# Dimensions:      (x: 2916, y: 2086)
# Coordinates:
#   * x            (x) float64 5.464e+05 5.464e+05 5.464e+05 ... 5.47e+05 5.47e+05
#   * y            (y) float64 5.73e+06 5.73e+06 5.73e+06 ... 5.73e+06 5.73e+06
#     spatial_ref  int32 0
# Data variables:
#     red          (y, x) uint8 ...
#     green        (y, x) uint8 ...
#     blue         (y, x) uint8 ...
#     nir          (y, x) uint8 ...
#     gap_mask     (y, x) uint8 ...
# Attributes:
#     AREA_OR_POINT:  Area

# %% [markdown]
# A data generator is defined that tiles the given xr.Dataset into multiple tiles and returns them in batches (row-wise). It also splits the data into training, validation, and test data sets. Additionally, data augmentation is included by rotating the training images by 90°, 180° and 270°.

# %%
# define tile size
tilesize = 224

# %%
class CustomImageDataGenerator(tf.keras.utils.Sequence):
    
    def __init__(self, ds, sampletype, tilesize=tilesize):
        self.ds   = ds
        self.ylen = self.ds.y.size // tilesize
        self.xlen = self.ds.x.size // tilesize
        self.sampletype = sampletype
        
    def __len__(self):
        
        return self.ylen

    def __getitem__(self, index):
        
        red   = self.ds.red[index*tilesize:(index+1)*tilesize,:-(self.ds.x.size%tilesize)]
        green = self.ds.green[index*tilesize:(index+1)*tilesize,:-(self.ds.x.size%tilesize)]
        blue  = self.ds.blue[index*tilesize:(index+1)*tilesize,:-(self.ds.x.size%tilesize)]
        gaps  = self.ds.gap_mask[index*tilesize:(index+1)*tilesize,:-(self.ds.x.size%tilesize)]
        
        rgb   = np.array([red,green,blue]).transpose(1,2,0)
        gaps  = np.array(gaps)
        
        # split into tiles
        rgb_tiles    = np.array(np.split(rgb, self.xlen,axis=1))
        target_tiles = np.array(np.split(gaps, self.xlen,axis=1))
        
        # depending on sampletype, return training, validation or test set (complete set)
        if self.sampletype == 'training' or self.sampletype == 'validation':
            
            rgb_tiles_tr, rgb_tiles_val, target_tiles_tr, target_tiles_val = train_test_split(rgb_tiles, target_tiles, shuffle=True, test_size=0.2, random_state=11)
            
            if self.sampletype == 'training':
                
                # data augmentation
                rgb_tiles_tr = np.concatenate((rgb_tiles_tr,
                                               tf.image.rot90(image=rgb_tiles_tr),
                                               tf.image.rot90(image=rgb_tiles_tr,k=2),
                                               tf.image.rot90(image=rgb_tiles_tr,k=3)),
                                              axis=0)

                target_tiles_tr = np.concatenate((target_tiles_tr, 
                                                  tf.image.rot90(np.expand_dims(target_tiles_tr,axis=-1))[:,:,:,0],
                                                  tf.image.rot90(np.expand_dims(target_tiles_tr,axis=-1),k=2)[:,:,:,0], 
                                                  tf.image.rot90(np.expand_dims(target_tiles_tr,axis=-1),k=3)[:,:,:,0]),
                                                 axis=0)
                
                ng = np.random.RandomState(7)
                indexes = ng.permutation(rgb_tiles_tr.shape[0])
                rgb_tiles_tr    = rgb_tiles_tr[indexes]
                target_tiles_tr = target_tiles_tr[indexes]
                
                return rgb_tiles_tr, target_tiles_tr
            
            else:
                
                return rgb_tiles_val, target_tiles_val
        
        if self.sampletype == 'test': 
            
            return rgb_tiles, target_tiles
        
        return None

# %% [markdown]
# ## 3. U-Net construction
# U-Net network structure, first introduced by [Ronneberger et al. (2015)](https://arxiv.org/abs/1505.04597), is used. The encoder is modified by using ResNet50V2 ([He et al. (2016)](https://arxiv.org/abs/1603.05027)) architecture as pretrained model.

# %%
# load pretrained ResNet50V2 model
base_model = tf.keras.applications.ResNet50V2(input_shape=[tilesize, tilesize, 3], include_top=False)
#base_model.summary()

# modify downstack/encoder for ResNet50V2
# use the activations of these layers
layer_names = [
    'conv1_conv',               # Initial Convolution layer
    'conv2_block3_preact_relu', # 56x56
    'conv3_block4_preact_relu', # 28x28
    'conv4_block6_preact_relu', # 14x14
    'post_bn',                  # 7x7
]

layers = [base_model.get_layer(name).output for name in layer_names]

# create the feature extraction model
down_stack = tf.keras.Model(inputs=base_model.input, outputs=layers)

# make this part of the model fix (not trainable)
down_stack.trainable = False

# modify upstack/decoder for ResNet50V2
up_stack = [
    pix2pix.upsample(896, 3),  # 7x7   -> 14x14
    pix2pix.upsample(448, 3),  # 14x14 -> 28x28
    pix2pix.upsample(224, 3),  # 28x28 -> 56x56
    pix2pix.upsample(112, 3),  # 56x56 -> 112x112
]

# define modified U-Net
def unet_model(output_channels):
    inputs = tf.keras.layers.Input(shape=[tilesize, tilesize, 3])
    x = inputs
    
    # downsampling through the model
    skips = down_stack(x)
    x = skips[-1]
    skips = reversed(skips[:-1])

    # upsampling and establishing the skip connections
    for up, skip in zip(up_stack, skips):
        x = up(x)
        concat = tf.keras.layers.Concatenate()
        x = concat([x, skip])

    # this is the last layer of the model
    last = tf.keras.layers.Conv2DTranspose(
        filters=output_channels, kernel_size=3, strides=2,
        padding='same')  #64x64 -> 128x128

    x = last(x)

    return tf.keras.Model(inputs=inputs, outputs=x)

# %%
# compile the model with 2 output channels/classes
OUTPUT_CHANNELS = 2

model = unet_model(output_channels=OUTPUT_CHANNELS)
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

#tf.keras.utils.plot_model(model, show_shapes=True)

# %%
# create an instance of the data generator
# hand over the training dataset (DOP with gap mask)
cidg_training   = CustomImageDataGenerator(train_dataset, sampletype="training")
cidg_validation = CustomImageDataGenerator(train_dataset, sampletype="validation")

# %% [markdown]
# ## 4. model training

# %%
# implement stop of training when validation loss
# has stopped improving for 15 epochs
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

model_history = model.fit(cidg_training,
                          validation_data=cidg_validation,
                          epochs=50,
                          initial_epoch=0,
                          callbacks=[early_stopping],
                          workers=multiprocessing.cpu_count() - 4)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 49s 5s/step - loss: 5.3422 - accuracy: 0.8280 - val_loss: 5.0937 - val_accuracy: 0.8859
# Epoch 2/50
# 9/9 [==============================] - 48s 5s/step - loss: 2.9794 - accuracy: 0.8874 - val_loss: 3.1296 - val_accuracy: 0.8775
# Epoch 3/50
# 9/9 [==============================] - 55s 6s/step - loss: 1.9347 - accuracy: 0.8676 - val_loss: 1.8614 - val_accuracy: 0.8752
# Epoch 4/50
# 9/9 [==============================] - 56s 6s/step - loss: 1.4457 - accuracy: 0.8611 - val_loss: 1.3679 - val_accuracy: 0.8740
# Epoch 5/50
# 9/9 [==============================] - 67s 7s/step - loss: 1.1319 - accuracy: 0.8812 - val_loss: 0.9545 - val_accuracy: 0.8517
# Epoch 6/50
# 9/9 [==============================] - 57s 6s/step - loss: 0.8253 - accuracy: 0.8784 - val_loss: 1.1755 - val_accuracy: 0.8901
# Epoch 7/50
# 9/9 [==============================] - 65s 7s/step - loss: 0.8066 - accuracy: 0.8813 - val_loss: 0.7200 - val_accuracy: 0.8786
# Epoch 8/50
# 9/9 [==============================] - 60s 7s/step - loss: 0.6277 - accuracy: 0.8766 - val_loss: 0.5523 - val_accuracy: 0.8807
# Epoch 9/50
# 9/9 [==============================] - 61s 7s/step - loss: 0.5064 - accuracy: 0.8852 - val_loss: 0.5445 - val_accuracy: 0.8881
# Epoch 10/50
# 9/9 [==============================] - 62s 7s/step - loss: 0.4567 - accuracy: 0.9003 - val_loss: 0.5333 - val_accuracy: 0.8414
# Epoch 11/50
# 9/9 [==============================] - 55s 6s/step - loss: 0.4400 - accuracy: 0.8902 - val_loss: 0.5459 - val_accuracy: 0.8271
# Epoch 12/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.4500 - accuracy: 0.8848 - val_loss: 0.4028 - val_accuracy: 0.8873
# Epoch 13/50
# 9/9 [==============================] - 51s 6s/step - loss: 0.4131 - accuracy: 0.8979 - val_loss: 0.4631 - val_accuracy: 0.8412
# Epoch 14/50
# 9/9 [==============================] - 47s 5s/step - loss: 0.3895 - accuracy: 0.9019 - val_loss: 0.6472 - val_accuracy: 0.8940
# Epoch 15/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.6012 - accuracy: 0.8852 - val_loss: 0.6192 - val_accuracy: 0.8942
# Epoch 16/50
# 9/9 [==============================] - 47s 5s/step - loss: 0.6517 - accuracy: 0.8787 - val_loss: 0.4552 - val_accuracy: 0.8456
# Epoch 17/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.5429 - accuracy: 0.8678 - val_loss: 0.4820 - val_accuracy: 0.8342
# Epoch 18/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.4275 - accuracy: 0.8925 - val_loss: 0.3634 - val_accuracy: 0.8814
# Epoch 19/50
# 9/9 [==============================] - 49s 5s/step - loss: 0.4363 - accuracy: 0.8818 - val_loss: 0.4762 - val_accuracy: 0.8962
# Epoch 20/50
# 9/9 [==============================] - 49s 5s/step - loss: 0.4591 - accuracy: 0.8907 - val_loss: 0.4761 - val_accuracy: 0.8984
# Epoch 21/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.4647 - accuracy: 0.8922 - val_loss: 0.4785 - val_accuracy: 0.8961
# Epoch 22/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.3625 - accuracy: 0.9082 - val_loss: 0.3918 - val_accuracy: 0.8777
# Epoch 23/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.3613 - accuracy: 0.8964 - val_loss: 0.4602 - val_accuracy: 0.8463
# Epoch 24/50
# 9/9 [==============================] - 47s 5s/step - loss: 0.3328 - accuracy: 0.9003 - val_loss: 0.3300 - val_accuracy: 0.8874
# Epoch 25/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.3300 - accuracy: 0.9070 - val_loss: 0.4476 - val_accuracy: 0.8198
# Epoch 26/50
# 9/9 [==============================] - 49s 5s/step - loss: 0.4203 - accuracy: 0.8836 - val_loss: 0.3525 - val_accuracy: 0.9003
# Epoch 27/50
# 9/9 [==============================] - 49s 6s/step - loss: 0.3966 - accuracy: 0.8974 - val_loss: 0.3082 - val_accuracy: 0.8985
# Epoch 28/50
# 9/9 [==============================] - 48s 5s/step - loss: 0.3323 - accuracy: 0.9089 - val_loss: 0.3581 - val_accuracy: 0.8729
# Epoch 29/50
# 9/9 [==============================] - 49s 5s/step - loss: 0.3438 - accuracy: 0.8826 - val_loss: 0.5548 - val_accuracy: 0.8948
# Epoch 30/50
# 9/9 [==============================] - 49s 6s/step - loss: 0.4354 - accuracy: 0.8967 - val_loss: 0.3263 - val_accuracy: 0.9018
# Epoch 31/50
# 9/9 [==============================] - 49s 6s/step - loss: 0.3486 - accuracy: 0.8978 - val_loss: 0.4272 - val_accuracy: 0.8961
# Epoch 32/50
# 9/9 [==============================] - 49s 5s/step - loss: 0.4251 - accuracy: 0.8879 - val_loss: 0.4439 - val_accuracy: 0.8955
# Epoch 33/50
# 9/9 [==============================] - 49s 6s/step - loss: 0.3701 - accuracy: 0.8945 - val_loss: 0.4122 - val_accuracy: 0.8707
# Epoch 34/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.3601 - accuracy: 0.8831 - val_loss: 0.5195 - val_accuracy: 0.8956
# Epoch 35/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.4580 - accuracy: 0.8996 - val_loss: 0.3438 - val_accuracy: 0.8697
# Epoch 36/50
# 9/9 [==============================] - 52s 6s/step - loss: 0.3552 - accuracy: 0.8982 - val_loss: 0.3169 - val_accuracy: 0.8873
# Epoch 37/50
# 9/9 [==============================] - 51s 6s/step - loss: 0.2917 - accuracy: 0.9096 - val_loss: 0.4109 - val_accuracy: 0.8980
# Epoch 38/50
# 9/9 [==============================] - 51s 6s/step - loss: 0.3632 - accuracy: 0.8935 - val_loss: 0.3047 - val_accuracy: 0.9063
# Epoch 39/50
# 9/9 [==============================] - 51s 6s/step - loss: 0.3404 - accuracy: 0.8968 - val_loss: 0.3795 - val_accuracy: 0.8476
# Epoch 40/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.3400 - accuracy: 0.8857 - val_loss: 0.4263 - val_accuracy: 0.9099
# Epoch 41/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.6028 - accuracy: 0.8827 - val_loss: 0.7363 - val_accuracy: 0.8948
# Epoch 42/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.5457 - accuracy: 0.8863 - val_loss: 0.5868 - val_accuracy: 0.8960
# Epoch 43/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.4562 - accuracy: 0.9097 - val_loss: 0.4335 - val_accuracy: 0.8649
# Epoch 44/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.3369 - accuracy: 0.8937 - val_loss: 0.3417 - val_accuracy: 0.9066
# Epoch 45/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.3491 - accuracy: 0.9038 - val_loss: 0.3000 - val_accuracy: 0.9161
# Epoch 46/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.3291 - accuracy: 0.9032 - val_loss: 0.3279 - val_accuracy: 0.9058
# Epoch 47/50
# 9/9 [==============================] - 49s 6s/step - loss: 0.3066 - accuracy: 0.9039 - val_loss: 0.5454 - val_accuracy: 0.8951
# Epoch 48/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.4104 - accuracy: 0.9001 - val_loss: 0.2981 - val_accuracy: 0.9052
# Epoch 49/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.3351 - accuracy: 0.9068 - val_loss: 0.2654 - val_accuracy: 0.9091
# Epoch 50/50
# 9/9 [==============================] - 50s 6s/step - loss: 0.2797 - accuracy: 0.9035 - val_loss: 0.2842 - val_accuracy: 0.8985

# %%
# plot accuracy and loss over the epochs
fig, ax = plt.subplots(1,2,figsize=(12,4))

ax[0].plot(model_history.history['accuracy'])
ax[0].plot(model_history.history['val_accuracy'])
ax[0].set_title('Model accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Training', 'Validation'], loc='lower right')

ax[1].plot(model_history.history['loss'])
ax[1].plot(model_history.history['val_loss'])
ax[1].set_title('Model loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Training', 'Validation'], loc='upper right')

plt.show()

# %%
# print maximum validation accurarcy
max(model_history.history['val_accuracy'])
# Out:
# 0.9160518050193787

# %%
# print minimum validation loss
min(model_history.history['val_loss'])
# Out:
# 0.26540181040763855

# %%
# function to display exemplary data
def plotExample(dataGen, batch_id, tile_id):
    batch = dataGen.__getitem__(batch_id)
    predi = model.predict(batch[0])
    
    fig, ax = plt.subplots(1,3,figsize=(16,6))
    ax[0].imshow(batch[0][tile_id]); ax[0].set_title("RGB input")
    ax[1].imshow(batch[1][tile_id], cmap="Greys", interpolation="None"); ax[1].set_title("True mask")
    ax[2].imshow(np.argmax(predi[tile_id], axis=-1), cmap="Greys", interpolation="None"); ax[2].set_title("Prediction")
    plt.show()
    
    return

# %%
# plot example prediction after training
plotExample(cidg_training,5,3)
# Out:
# 2/2 [==============================] - 4s 744ms/step

# %%
model.save(processed_data_dir / 'resnet50v2_unet_data_aug')
# Out:
# INFO:tensorflow:Assets written to: P:\KfP\Aktiv\KfP_FE\canopy_gap_detection\gap_detection\data\processed_data\resnet50v2_unet_data_aug\assets
# INFO:tensorflow:Assets written to: P:\KfP\Aktiv\KfP_FE\canopy_gap_detection\gap_detection\data\processed_data\resnet50v2_unet_data_aug\assets
